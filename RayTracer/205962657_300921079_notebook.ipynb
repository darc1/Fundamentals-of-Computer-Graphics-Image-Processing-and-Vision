# %% [markdown]
# # Homework 2 - Creative
# ### Robert Haik: 205962657 Chen Dar: 300921079
#
# Added support for motion blur for sphere and triangle.
#
# The added parameters are x,y,z for movement direction and a size for the movement size.
# if these parameters are not specified a static object will be created.
# for example:
#
# ```
# # Sphere:	cx   	cy   	cz  	radius 	mat_idx movement_x movement_y movement_z movement_size
# sph		0.5  	0.0    0    0.15    	1
# sph		0.25  	0.0    0    0.15    	1   0.5   0.5   0   0.05
#
# ```
#
# jar is: `RayTracer.jar`
# exection with `java -jar target/RayTracer.jar <scene_file> <output_file> width height`.
# `render` function will render an image using a scene file, and save it to out put.

# %%
import os
from IPython.display import Image
imgs_folder = "rendered"
os.makedirs(imgs_folder, exist_ok=True)

def render(scene_file, output_file):
    img_path = os.path.join(imgs_folder, output_file)
    os.system(f'java -jar RayTracer.jar "{scene_file}" "{img_path}"')
    return Image(img_path)

# %% [markdown]
# ## Render: `scenes/test.txt`
#
# ```
# sph		0.9  	0.0    0    0.25    	1
# sph		0.0 	0.9    0   	0.25        1   0.5   -0.5   0   0.1
# sph		-0.9 	0.0    0	0.25        1   0.5   0.5   0   0.3
# sph		0.0 	-0.9    0	0.25        1   -0.5   0.5   0   0.5
# ```

# %%
render("scenes/test.txt", "test.png")
