# %% [markdown]
# # Homework 2
# ### Robert Haik: 205962657 Chen Dar: 300921079
#
# jar is: `RayTracer.jar`
# exection with `java -jar target/RayTracer.jar <scene_file> <output_file> width height`.
# `render` function will render an image using a scene file, and save it to out put.

# %%
import os
from IPython.display import Image
imgs_folder = "rendered"
os.makedirs(imgs_folder, exist_ok=True)

def render(scene_file, output_file):
    img_path = os.path.join(imgs_folder, output_file)
    os.system(f'java -jar RayTracer.jar "{scene_file}" "{img_path}"')
    return Image(img_path)

# %% [markdown]
# ## Render: `scenes/Spheres.txt`

# %%
render("scenes/Spheres.txt", "Spheres.png")

# %% [markdown]
# ## Render: `scenes/Pool.txt`

# %%
render("scenes/Pool.txt", "Pool.png")

# %% [markdown]
# ## Render: `scenes/Room10.txt`

# %%
render("scenes/Room10.txt", "Room10.png")

# %% [markdown]
# ## Render: `scenes/Room1.txt`

# %%
render("scenes/Room1.txt", "Room1.png")

# %% [markdown]
# ## Render: `scenes/Transparency.txt`

# %%
render("scenes/Transparency.txt", "Transparency.png")

# %% [markdown]
# ## Render: `scenes/Triangle2.txt`

# %%
render("scenes/Triangle2.txt", "Triangle2.png")

# %% [markdown]
# ## Render: `scenes/Triangle.txt`

# %%
render("scenes/Triangle.txt", "Triangle.png")
